# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport krokker, NetModel

from krokker import main, last_train_start

main((
    "--train",
    "--train-epoch-count", "1"
))

print(last_train_start())
# Out:
# hellowee
# train start time: 2019-02-11_17-19-18
# Epoch 1/1
# 20/20 [==============================] - 12s 601ms/step - loss: 0.2044 - tf_accuracy: 0.7168
# Model struct has been stored as model_2019-02-11_17-19-18.json
# Model weights has been stored as model_2019-02-11_17-19-18.hdh5
# 2019-02-11_17-19-18

# %%
print(last_train_start())
# Out:
# 2019-02-11_17-19-18

# %%
# %aimport SiamTestGenerator, SoloTestGenerator, NetModel

model_mark = "2019-02-11_16-03-52"
model_mark = last_train_start()

main((
    "--test", model_mark,
    "--test-group-count", "100"
))
# Out:
# hellowee
# 200/200 [==============================] - 1s 4ms/step
# Размерность пространства отображения: (32,)
# Классов в сравнении 100
# accuracy: 0.4306
