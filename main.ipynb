# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport krokker, NetModel

from krokker import main, last_train_start

main((
    "--train",
    "--train-epoch-count", "1000",
    "--model-mark", last_train_start()
))
# Out:
# Using TensorFlow backend.
# train start time: 2019-02-12_01-10-49
# Epoch 1/1
# 20/20 [==============================] - 10s 521ms/step - loss: 0.1207 - tf_accuracy: 0.8914
# Model struct has been stored as model_2019-02-12_01-10-49.json
# Model weights has been stored as model_2019-02-12_01-10-49.hdh5

# %%
print(last_train_start())
# Out:
# 2019-02-12_01-10-49

# %%
# %aimport SiamTestGenerator, SoloTestGenerator, NetModel

model_mark = last_train_start()

main((
    "--test",
    "--model-mark", last_train_start(),
    "--test-group-count", "100"
))
# Out:
# 200/200 [==============================] - 1s 5ms/step
# Размерность пространства отображения: (128,)
# Классов в сравнении 100
# accuracy: 0.5785
