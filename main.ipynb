# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport krokker, NetModel, UniformGenerator

from krokker import main, last_train_start
# Out:
# Using TensorFlow backend.

# %%
model_mark = last_train_start()
#model_mark = "2019-02-12_12-07-38"

main((
    "--train",
    "--train-epoch-count", "2000",
    "--model-mark", model_mark
))

# %%
print(last_train_start())

# %%
# %aimport SiamTestGenerator, SoloTestGenerator, NetModel, NetTest

model_mark = last_train_start()
#model_mark = "2019-02-12_01-15-19"
#model_mark = "2019-02-12_21-15-08"
#model_mark = "2019-02-12_12-07-38"
model_mark = "2019-02-12_01-15-19" # 90/10
#model_mark = "2019-02-11_23-37-40" # worst
model_mark = "1024-128_pn10x90_sgd-2000"

main((
    "--test",
    "--model-mark", model_mark,
    "--test-group-count", "10"
))
# Out:
# 20/20 [==============================] - 0s 23ms/step
# Размерность пространства отображения: (128,)
# Классов в сравнении 10
# accuracy: 0.89
